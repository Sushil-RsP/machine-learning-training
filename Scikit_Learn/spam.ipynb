# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer

# %%
data = pd.read_csv(r"C:\Users\LENOVO\Downloads\Indian_Lottery_Scams.csv")
data.head()

# %%
x = data.drop('Scam Status',axis=1)
x.head()

# %%
y = data['Scam Status']
y.head()

# %%
print(x.shape) # output (500, 3)
print(y.shape) # output (500,)

# %%
categorical = ['Email Subject', 'Sender Email Address', 'Email Body']

# %%
preprocesor = ColumnTransformer(
    [
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical)
    ]
)

# %%
pipline = make_pipeline(preprocesor, MultinomialNB())

# %%
pipline.fit(x,y)

# %%
def classify_new_reviews(new_subject, new_sender, new_review):
    new_review_df = pd.DataFrame({
        'Email Subject': [new_subject],  # Replace with a dummy subject
        'Sender Email Address': [new_sender],  # Replace with a dummy email
        'Email Body': [new_review]  # Use the actual review as the body
    })
    predict = pipline.predict(new_review_df)  # Use the pipeline to predict
    if predict[0] == 'Scam':
        return "Negative"
    else:
        return "Positive"

new_subject = input("enter a subject : ")
new_sender = input("enter a sender : ")
new_review = input("enter a review : ")

#user_input = [new_subject, new_sender, new_review]
result = classify_new_reviews(new_subject, new_sender, new_review)
print(f'review is {result}')

# %%
user_input = {
    "Email Body": 'Dear Winner, We are pleased to inform you that'
}

# %%
input = pd.DataFrame([user_input])

# %%
pipline.predict(input)

# %%
print(x.shape)  # output (3, 5)
print(y.shape) # output (500,)

# %%
model = MultinomialNB()
model.fit(x, y)

# %%
print("Shape of x (features):", x.shape)  # Should be (n_samples, n_features)
print("Shape of y (target):", y.shape)
